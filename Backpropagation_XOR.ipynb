# %% [markdown]
# <a href="https://colab.research.google.com/github/sriharshan136/Flutter-Grocery-Application/blob/main/Backpropagation_XOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

# %%
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

# %%
def sigmoid_derivative(x):
  return sigmoid(x) * (1 - sigmoid(x))

# %%
# XOR data
inputs_X = [[0, 0], [0, 1], [1, 0], [1, 1]]
outputs_R = [0, 1, 1, 0]

# Add X0 = 1 to the inputs
inputs_X = np.insert(inputs_X, 0, 1, axis=1)

learning_rate = 0.1

print(f"Learning Rate: {learning_rate}")
# Out:
# Learning Rate: 0.1

# %%
def forward_propagation(inputs):
  Z = [1]
  for wi in W:
    Z.append(sigmoid(sum([x*w for x, w in zip(inputs, wi)])))

  Y = sigmoid(sum([z*v for z, v in zip(Z, V[0])]))

  return Y

# %%
#Backprogation Algorithm - Updating weights for each input.
#Training
def train(W, V, iterations = 1000):
  for epoch in range(iterations):
    for n in range(len(inputs_X)):
      inputs = inputs_X[n]
      outputs = outputs_R[n]

      #Forward Propagation
      Z = [1]
      for wi in W:
        Z.append(sigmoid(sum([x*w for x, w in zip(inputs, wi)])))

      Y = sigmoid(sum([z*v for z, v in zip(Z, V[0])]))

      #Backward Propagation
      error = outputs - Y

      delta_V = [learning_rate * error * z for z in Z]

      delta_W = np.zeros((2, 3))
      for i in range(1, len(Z)):
        for j in range(len(inputs)):
          delta_W[i-1][j] = learning_rate * error * V[0][i] * Z[i] * (1 - Z[i]) * inputs[j]

      V += delta_V
      W += delta_W

    if epoch % 100 == 0:
      predictions = []
      for i in range(len(inputs_X)):
        predictions.append(round(forward_propagation(inputs_X[i])))
      accuracy = accuracy_score(outputs_R, predictions)
      squared_error = sum([(o-p)**2 for o, p in zip(outputs_R, predictions)])
      mse = mean_squared_error(outputs_R, predictions)
      print(f"Epoch: [{epoch}/{iterations}]")
      print(f"Predicted Outputs: {predictions}")
      print(f"Accuracy: {accuracy}, Squared Error: {squared_error}, MSE: {mse}")

  print(f"Predicted Outputs: {predictions}")
  print(f"Final weights:")
  print(f"\tInput Layer Weights: {W[0]}, {W[1]}")
  print(f"\tHidden Layer Weights: {V[0]}")

# %%
np.random.seed(100)
for i in range(5):
  # Initialize weights randomly
  W = np.random.randn(2, 3)
  V = np.random.randn(1, 3)
  print(f"Backpropagation Sample: [{i+1}/5]")
  print(f"Intial Random weights:")
  print(f"\tInput Layer Weights: {W[0]}, {W[1]}")
  print(f"\tHidden Layer Weights: {V[0]}")
  print(f"Learning Rate: {learning_rate}")
  train(W, V)

  # Print a dividing line after each iteration
  print("-" * 100)
# Out:
# Backpropagation Sample: [1/5]
# Intial Random weights:
# 	Input Layer Weights: [-1.74976547  0.3426804   1.1530358 ], [-0.25243604  0.98132079  0.51421884]
# 	Hidden Layer Weights: [ 0.22117967 -1.07004333 -0.18949583]
# Learning Rate: 0.1
# Epoch: [0/1000]
# Predicted Outputs: [1, 0, 0, 0]
# Accuracy: 0.25, Squared Error: 3, MSE: 0.75
# Epoch: [100/1000]
# Predicted Outputs: [1, 0, 1, 0]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [200/1000]
# Predicted Outputs: [1, 1, 1, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [300/1000]
# Predicted Outputs: [1, 1, 1, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [400/1000]
# Predicted Outputs: [1, 1, 1, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [500/1000]
# Predicted Outputs: [1, 1, 1, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [600/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [700/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [800/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [900/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Predicted Outputs: [0, 1, 1, 0]
# Final weights:
# 	Input Layer Weights: [-6.54021441  4.23441161  4.20947922], [-2.03426883  4.80826004  4.80789846]
# 	Hidden Layer Weights: [-2.97005832 -7.09029094  6.55439905]
# ----------------------------------------------------------------------------------------------------
# Backpropagation Sample: [2/5]
# Intial Random weights:
# 	Input Layer Weights: [ 0.25500144 -0.45802699  0.43516349], [-0.58359505  0.81684707  0.67272081]
# 	Hidden Layer Weights: [-0.10441114 -0.53128038  1.02973269]
# Learning Rate: 0.1
# Epoch: [0/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [100/1000]
# Predicted Outputs: [0, 0, 1, 1]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [200/1000]
# Predicted Outputs: [0, 0, 1, 1]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [300/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [400/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [500/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [600/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [700/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [800/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [900/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Predicted Outputs: [0, 1, 1, 0]
# Final weights:
# 	Input Layer Weights: [-3.0070466   2.13293499  2.15017101], [-1.71048033  5.12486679  5.50465383]
# 	Hidden Layer Weights: [-2.5805755  -5.10588789  5.61091541]
# ----------------------------------------------------------------------------------------------------
# Backpropagation Sample: [3/5]
# Intial Random weights:
# 	Input Layer Weights: [-0.43813562 -1.11831825  1.61898166], [ 1.54160517 -0.25187914 -0.84243574]
# 	Hidden Layer Weights: [0.18451869 0.9370822  0.73100034]
# Learning Rate: 0.1
# Epoch: [0/1000]
# Predicted Outputs: [1, 1, 1, 1]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [100/1000]
# Predicted Outputs: [1, 1, 0, 0]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [200/1000]
# Predicted Outputs: [1, 1, 0, 0]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [300/1000]
# Predicted Outputs: [0, 1, 0, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [400/1000]
# Predicted Outputs: [0, 1, 0, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [500/1000]
# Predicted Outputs: [0, 1, 0, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [600/1000]
# Predicted Outputs: [0, 1, 0, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [700/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [800/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [900/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Predicted Outputs: [0, 1, 1, 0]
# Final weights:
# 	Input Layer Weights: [-3.49426458 -5.59873138  5.71128109], [-2.11801405  4.04976774 -4.63576385]
# 	Hidden Layer Weights: [-3.21608275  6.81757021  6.42929251]
# ----------------------------------------------------------------------------------------------------
# Backpropagation Sample: [4/5]
# Intial Random weights:
# 	Input Layer Weights: [ 1.36155613 -0.32623806  0.05567601], [ 0.22239961 -1.443217   -0.75635231]
# 	Hidden Layer Weights: [ 0.81645401  0.75044476 -0.45594693]
# Learning Rate: 0.1
# Epoch: [0/1000]
# Predicted Outputs: [1, 1, 1, 1]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [100/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [200/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [300/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [400/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [500/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [600/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [700/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [800/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [900/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Predicted Outputs: [0, 1, 1, 0]
# Final weights:
# 	Input Layer Weights: [ 5.50768114 -3.77583523 -3.75962926], [ 2.05102324 -5.59091988 -5.59046519]
# 	Hidden Layer Weights: [-2.95301781  6.88910312 -7.78592714]
# ----------------------------------------------------------------------------------------------------
# Backpropagation Sample: [5/5]
# Intial Random weights:
# 	Input Layer Weights: [ 1.18962227 -1.69061683 -1.35639905], [-1.23243451 -0.54443916 -0.66817174]
# 	Hidden Layer Weights: [ 0.00731456 -0.61293874  1.29974807]
# Learning Rate: 0.1
# Epoch: [0/1000]
# Predicted Outputs: [0, 0, 0, 1]
# Accuracy: 0.25, Squared Error: 3, MSE: 0.75
# Epoch: [100/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [200/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [300/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [400/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [500/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [600/1000]
# Predicted Outputs: [0, 1, 1, 1]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [700/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [800/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [900/1000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Predicted Outputs: [0, 1, 1, 0]
# Final weights:
# 	Input Layer Weights: [ 2.00903733 -5.77569018 -5.89729562], [ 4.54728449 -3.1969768  -3.1881601 ]
# 	Hidden Layer Weights: [-2.5380217  -7.41645401  6.30273989]
# ----------------------------------------------------------------------------------------------------

# %%
#Backprogation Algorithm - Batch version.
#Training
def batch_train(W, V, iterations = 1000):
  for epoch in range(iterations):
    delta_V_sum = np.zeros_like(V)
    delta_W_sum = np.zeros_like(W)
    for n in range(len(inputs_X)):
      inputs = inputs_X[n]
      outputs = outputs_R[n]

      #Forward Propagation
      Z = [1]
      for wi in W:
        Z.append(sigmoid(sum([x*w for x, w in zip(inputs, wi)])))

      Y = sigmoid(sum([z*v for z, v in zip(Z, V[0])]))

      #Backward Propagation
      error = outputs - Y

      delta_V = [learning_rate * error * z for z in Z]

      delta_W = np.zeros((2, 3))
      for i in range(1, len(Z)):
        for j in range(len(inputs)):
          delta_W[i-1][j] = learning_rate * error * V[0][i] * Z[i] * (1 - Z[i]) * inputs[j]

      delta_V_sum += delta_V
      delta_W_sum += delta_W

    # Update weights after processing the entire batch
    V += delta_V_sum / len(inputs_X)
    W += delta_W_sum / len(inputs_X)

    if epoch % 1000 == 0:
      predictions = []
      for i in range(len(inputs_X)):
        predictions.append(round(forward_propagation(inputs_X[i])))
      accuracy = accuracy_score(outputs_R, predictions)
      squared_error = sum([(o-p)**2 for o, p in zip(outputs_R, predictions)])
      mse = mean_squared_error(outputs_R, predictions)
      print(f"Epoch: [{epoch}/{iterations}]")
      print(f"Predicted Outputs: {predictions}")
      print(f"Accuracy: {accuracy}, Squared Error: {squared_error}, MSE: {mse}")

  print(f"Predicted Outputs: {predictions}")
  print(f"Final weights:")
  print(f"\tInput Layer Weights: {W[0]}, {W[1]}")
  print(f"\tHidden Layer Weights: {V[0]}")

# %% [markdown]
# **The batch version required a higher number of training iterations compared to the single version to achieve similar accuracy.**

# %%
#Batch Version
np.random.seed(101)
for i in range(5):
  # Initialize weights randomly
  W = np.random.randn(2, 3)
  V = np.random.randn(1, 3)
  print(f"Backpropagation Batch Version Sample: [{i+1}/5]")
  print(f"Intial Random weights:")
  print(f"\tInput Layer Weights: {W[0]}, {W[1]}")
  print(f"\tHidden Layer Weights: {V[0]}")
  print(f"Learning Rate: {learning_rate}")
  batch_train(W, V, iterations=10000)

  # Print a dividing line after each iteration
  print("-" * 100)
# Out:
# Backpropagation Batch Version Sample: [1/5]
# Intial Random weights:
# 	Input Layer Weights: [2.70684984 0.62813271 0.90796945], [ 0.50382575  0.65111795 -0.31931804]
# 	Hidden Layer Weights: [-0.84807698  0.60596535 -2.01816824]
# Learning Rate: 0.1
# Epoch: [0/10000]
# Predicted Outputs: [0, 0, 0, 0]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [1000/10000]
# Predicted Outputs: [0, 1, 0, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [2000/10000]
# Predicted Outputs: [0, 1, 0, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [3000/10000]
# Predicted Outputs: [0, 1, 0, 1]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [4000/10000]
# Predicted Outputs: [0, 1, 0, 1]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [5000/10000]
# Predicted Outputs: [0, 1, 0, 1]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [6000/10000]
# Predicted Outputs: [0, 1, 0, 1]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [7000/10000]
# Predicted Outputs: [0, 1, 0, 1]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [8000/10000]
# Predicted Outputs: [0, 1, 0, 1]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [9000/10000]
# Predicted Outputs: [0, 1, 0, 1]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Predicted Outputs: [0, 1, 0, 1]
# Final weights:
# 	Input Layer Weights: [-1.10367665  7.06873887  3.83833946], [ 2.98078172  7.43375698 -4.35243675]
# 	Hidden Layer Weights: [-0.06854972  6.42783292 -6.36110585]
# ----------------------------------------------------------------------------------------------------
# Backpropagation Batch Version Sample: [2/5]
# Intial Random weights:
# 	Input Layer Weights: [ 0.74012206  0.52881349 -0.58900053], [ 0.18869531 -0.75887206 -0.93323722]
# 	Hidden Layer Weights: [0.95505651 0.19079432 1.97875732]
# Learning Rate: 0.1
# Epoch: [0/10000]
# Predicted Outputs: [1, 1, 1, 1]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [1000/10000]
# Predicted Outputs: [1, 1, 0, 0]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [2000/10000]
# Predicted Outputs: [0, 1, 0, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [3000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [4000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [5000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [6000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [7000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [8000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [9000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Predicted Outputs: [0, 1, 1, 0]
# Final weights:
# 	Input Layer Weights: [ 3.14751228  6.41540245 -6.23202669], [-3.05613704  5.70917822 -5.9792391 ]
# 	Hidden Layer Weights: [ 4.42857545 -9.57543595 10.19009939]
# ----------------------------------------------------------------------------------------------------
# Backpropagation Batch Version Sample: [3/5]
# Intial Random weights:
# 	Input Layer Weights: [2.60596728 0.68350889 0.30266545], [ 1.69372293 -1.70608593 -1.15911942]
# 	Hidden Layer Weights: [-0.13484072  0.39052784  0.16690464]
# Learning Rate: 0.1
# Epoch: [0/10000]
# Predicted Outputs: [1, 1, 1, 1]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [1000/10000]
# Predicted Outputs: [1, 1, 1, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [2000/10000]
# Predicted Outputs: [1, 1, 1, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [3000/10000]
# Predicted Outputs: [1, 1, 1, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [4000/10000]
# Predicted Outputs: [1, 1, 1, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [5000/10000]
# Predicted Outputs: [1, 1, 1, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [6000/10000]
# Predicted Outputs: [1, 1, 1, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [7000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [8000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [9000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Predicted Outputs: [0, 1, 1, 0]
# Final weights:
# 	Input Layer Weights: [ 2.11236516 -5.13221496 -5.18937796], [ 8.92760009 -5.83568003 -5.92563014]
# 	Hidden Layer Weights: [-3.8135472  -8.76270625  8.15195212]
# ----------------------------------------------------------------------------------------------------
# Backpropagation Batch Version Sample: [4/5]
# Intial Random weights:
# 	Input Layer Weights: [0.18450186 0.80770591 0.07295968], [ 0.63878701  0.3296463  -0.49710402]
# 	Hidden Layer Weights: [-0.7540697  -0.9434064   0.48475165]
# Learning Rate: 0.1
# Epoch: [0/10000]
# Predicted Outputs: [0, 0, 0, 0]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [1000/10000]
# Predicted Outputs: [1, 1, 0, 0]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [2000/10000]
# Predicted Outputs: [1, 1, 0, 0]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [3000/10000]
# Predicted Outputs: [1, 1, 0, 0]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [4000/10000]
# Predicted Outputs: [0, 1, 0, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [5000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [6000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [7000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [8000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [9000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Predicted Outputs: [0, 1, 1, 0]
# Final weights:
# 	Input Layer Weights: [ 3.15832693  6.31966693 -6.18401673], [-2.83802504  5.30307277 -5.59453695]
# 	Hidden Layer Weights: [ 4.04273031 -8.82075634  9.47266226]
# ----------------------------------------------------------------------------------------------------
# Backpropagation Batch Version Sample: [5/5]
# Intial Random weights:
# 	Input Layer Weights: [-0.11677332  1.9017548   0.23812696], [ 1.99665229 -0.9932635   0.1967995 ]
# 	Hidden Layer Weights: [-1.13664459e+00  3.66479606e-04  1.02598415e+00]
# Learning Rate: 0.1
# Epoch: [0/10000]
# Predicted Outputs: [0, 0, 0, 0]
# Accuracy: 0.5, Squared Error: 2, MSE: 0.5
# Epoch: [1000/10000]
# Predicted Outputs: [1, 1, 1, 0]
# Accuracy: 0.75, Squared Error: 1, MSE: 0.25
# Epoch: [2000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [3000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [4000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [5000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [6000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [7000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [8000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Epoch: [9000/10000]
# Predicted Outputs: [0, 1, 1, 0]
# Accuracy: 1.0, Squared Error: 0, MSE: 0.0
# Predicted Outputs: [0, 1, 1, 0]
# Final weights:
# 	Input Layer Weights: [-3.0265372   6.77330912  6.76545166], [ 8.13211516 -5.42793719 -5.42636378]
# 	Hidden Layer Weights: [-12.39622819   8.43553979   8.484135  ]
# ----------------------------------------------------------------------------------------------------
